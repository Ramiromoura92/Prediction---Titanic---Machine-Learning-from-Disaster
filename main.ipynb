# %%
# !pip install pandas 
# !pip install sklearn 
# !pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.9/11.9 MB 6.8 MB/s eta 0:00:00m eta 0:00:010:0101
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 6.9 MB/s eta 0:00:00m eta 0:00:010:01:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 930.9/930.9 KB 6.6 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# ...

# %%
import pandas as pd

uri = 'train.csv'
dados = pd.read_csv(uri)
dados.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
a_renomear = {
    'PassengerId':'cod_passageiro',
    'Survived':'sobreviventes',
    'Pclass':'classe_passageiro',
    'Name':'nome',
    'Sex':'sexo',
    'Age':'idade',
    'SibSp':'irmaoeconjugues',
    'Parch':'paisefilhos',
    'Ticket':'bilhete',
    'Fare':'tarifa',
    'Cabin':'cabine',
    'Embarked':'Embarcou'
    
    }

dados = dados.rename(columns=a_renomear)
dados.head(50)
# Out:
#     cod_passageiro  sobreviventes  classe_passageiro  \
# 0                1              0                  3
# 1                2              1                  1
# 2                3              1                  3
# 3                4              1                  1
# 4                5              0                  3
# 5                6              0                  3
# 6                7              0                  1
# 7                8              0                  3
# 8                9              1                  3
# 9               10              1                  2
# 10              11              1                  3
# 11              12              1                  1
# 12              13              0                  3
# 13              14              0                  3
# 14              15              0                  3
# 15              16              1                  2
# 16              17              0                  3
# ...

# %%
a_trocar = {
    'male':1,
    'female':0
}
dados.sexo = dados.sexo.map(a_trocar)

dados.describe()
# Out:
#        cod_passageiro  sobreviventes  classe_passageiro  sexo       idade  \
# count      891.000000     891.000000         891.000000   0.0  714.000000
# mean       446.000000       0.383838           2.308642   NaN   29.699118
# std        257.353842       0.486592           0.836071   NaN   14.526497
# min          1.000000       0.000000           1.000000   NaN    0.420000
# 25%        223.500000       0.000000           2.000000   NaN   20.125000
# 50%        446.000000       0.000000           3.000000   NaN   28.000000
# 75%        668.500000       1.000000           3.000000   NaN   38.000000
# max        891.000000       1.000000           3.000000   NaN   80.000000
#
#        irmaoeconjugues  paisefilhos      tarifa
# count       891.000000   891.000000  891.000000
# mean          0.523008     0.381594   32.204208
# std           1.102743     0.806057   49.693429
# min           0.000000     0.000000    0.000000
# 25%           0.000000     0.000000    7.910400
# ...

# %%
import matplotlib.pyplot as plt

dados.plot.hist(column=["tarifa"], by="sobreviventes", figsize=(10, 8))
# Out:
# array([<AxesSubplot:title={'center':'0'}, ylabel='Frequency'>,
#        <AxesSubplot:title={'center':'1'}, ylabel='Frequency'>],
#       dtype=object)

# %%
x = dados [['classe_passageiro','sexo','irmaoeconjugues','paisefilhos']]
y = dados ['sobreviventes']

treino_x = x
treino_y = y
teste_x = x
teste_y = y

# %%
from sklearn.model_selection import train_test_split 
from sklearn.svm import LinearSVC
from sklearn.metrics import accuracy_score
from sklearn.svm import SVC
import numpy as np


SEED = 5  
np.random.seed(SEED)
treino_x, teste_x, treino_y, teste_y = train_test_split(x, y, test_size = 0.2,stratify = y) 
print("Treinaremos com %d elementos e testaremos com %d elementos" % (len(treino_x),len(teste_x)))

modelo = SVC(C=1, kernel='poly',degree=3,gamma='auto')
modelo.fit(treino_x, treino_y)

previsoes = modelo.predict(teste_x) 
taxa_de_acerto = accuracy_score(teste_y, previsoes)* 100 
print("A acurácia foi %.2f" % taxa_de_acerto)
# Out:
# Treinaremos com 712 elementos e testaremos com 179 elementos
# A acurácia foi 80.45

# %%
from sklearn.dummy import DummyClassifier #Estimador "bobo" para eu ter minha baseline e comprar com o meu modelo.
dummy_stratified = DummyClassifier()
dummy_stratified.fit(x, y)
acuracia = dummy_stratified.score(x, y) #Return the mean accuracy on the given test data and labels.

print("A acurácia do dummy stratified foi %.2f" % acuracia)
# Out:
# A acurácia do dummy stratified foi 0.62

# %%
from sklearn.dummy import DummyClassifier #Estimador "bobo" para eu ter minha baseline e comprar com o meu modelo.
dummy_mostfrequent = DummyClassifier()
dummy_mostfrequent.fit(treino_x, treino_y)
previsoes = dummy_mostfrequent.predict(teste_x)

taxa_de_acerto = accuracy_score(teste_y, previsoes)* 100 #Imprimir minha taxa de acerto ou "acurácia" - Comparação com os meus dados reais de teste
print("A acurácia do dummy stratified foi %.2f" % taxa_de_acerto)
# Out:
# A acurácia do dummy stratified foi 61.45

# %%
uri2 = 'test.csv'
dados2 = pd.read_csv(uri2)
dados2.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
a_renomear2 = {
    'Survived':'sobreviventes',
    'Pclass':'classe_passageiro',
    'Name':'nome',
    'Sex':'sexo',
    'Age':'idade',
    'SibSp':'irmaoeconjugues',
    'Parch':'paisefilhos',
    'Ticket':'bilhete',
    'Fare':'tarifa',
    'Cabin':'cabine',
    'Embarked':'Embarcou'
    
    }

dados2 = dados2.rename(columns=a_renomear2)
dados2.head(50)


a_trocar2 = {
    'male':1,
    'female':0
}

dados2.sexo = dados2.sexo.map(a_trocar2)
dados2.head()
# Out:
#    PassengerId  classe_passageiro  \
# 0          892                  3
# 1          893                  3
# 2          894                  2
# 3          895                  3
# 4          896                  3
#
#                                            nome  sexo  idade  irmaoeconjugues  \
# 0                              Kelly, Mr. James     1   34.5                0
# 1              Wilkes, Mrs. James (Ellen Needs)     0   47.0                1
# 2                     Myles, Mr. Thomas Francis     1   62.0                0
# 3                              Wirz, Mr. Albert     1   27.0                0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)     0   22.0                1
#
#    paisefilhos  bilhete   tarifa cabine Embarcou
# 0            0   330911   7.8292    NaN        Q
# 1            0   363272   7.0000    NaN        S
# 2            0   240276   9.6875    NaN        Q
# 3            0   315154   8.6625    NaN        S
# ...

# %%
x = dados2 [['classe_passageiro','sexo','irmaoeconjugues','paisefilhos']]

# %%
dados2['Survived'] = modelo.predict(x)

# %%
dados2.head()
# Out:
#    PassengerId  classe_passageiro  \
# 0          892                  3
# 1          893                  3
# 2          894                  2
# 3          895                  3
# 4          896                  3
#
#                                            nome  sexo  idade  irmaoeconjugues  \
# 0                              Kelly, Mr. James     1   34.5                0
# 1              Wilkes, Mrs. James (Ellen Needs)     0   47.0                1
# 2                     Myles, Mr. Thomas Francis     1   62.0                0
# 3                              Wirz, Mr. Albert     1   27.0                0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)     0   22.0                1
#
#    paisefilhos  bilhete   tarifa cabine Embarcou  Survived
# 0            0   330911   7.8292    NaN        Q         0
# 1            0   363272   7.0000    NaN        S         1
# 2            0   240276   9.6875    NaN        Q         0
# ...

# %%
result = dados2[['PassengerId', 'Survived']]
result.head()
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         1
# 2          894         0
# 3          895         0
# 4          896         1

# %%
result.to_csv("output.csv", index = False)

# %%
# Out:
#    Unnamed: 0  PassengerId  Survived
# 0           0          892         0
# 1           1          893         1
# 2           2          894         0
# 3           3          895         0
# 4           4          896         1

# %%
uri3 = 'my_submission.csv'
dados4 = pd.read_csv(uri3)
dados4.head()
